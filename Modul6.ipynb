# %% [markdown]
# <a href="https://colab.research.google.com/github/ivandwinugraha/vandwi/blob/master/Modul6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Modul 6 Pemrograman Fungsional
# Functional programming on study case of gamification.

# %%
1.   Disusun oleh:

*   Moch. Daffa Shafwan C.
*   Muhammad Yusril Hasanuddin

2.   Diaudit oleh:


*   Wildan Suharso

Presented by: TIM LAB-IT
Universitas Muhammadiyah Malang

# %% [markdown]
# # PERSIAPAN MATERI

# %% [markdown]
# *   Materi pada modul ini merupakan perpaduan materi yang terdapat pada modul 1-4.

# %% [markdown]
# # TUJUAN

# %% [markdown]
# 1. Mahasiswa mampu mengimplementasikan pemrograman fungsional pada studi kasus logika pemrograman.
# 2. Mahasiswa mampu mengimplementasikan pemrograman fungsional pada masalah gamification sederhana.

# %% [markdown]
# # TARGET MODUL

# %% [markdown]
# Mahasiswa mampu mengimplementasikan pemrograman fungsional dalam penyelesaian masalah gamification sederhana.

# %% [markdown]
# ## PERSIAPAN SOFTWARE/APLIKASI

# %% [markdown]
# • PC / Laptop
#
# • Google Collab
#
# • Pycharm
#
# • Anaconda

# %% [markdown]
# # KEGIATAN PERCOBAAN

# %% [markdown]
# ## Percobaan 1 (Mobile Legends Simple Game)

# %% [markdown]
# Dengan diberikan dictionary allheroes, magic, attack, dan spell berikut ini,
# Buatlah simple gamification dengan ketentuan sebagai berikut:
#
# 1. Ketika game dijalankan maka user akan memilih 1 hero yang akan dia mainkan.
#
# 2. Selanjutnya user akan memilih spell yang akan dia gunakan.
#
# 3. Setelah user menentukan hero dan spellnya, maka user dipersilahkan memilih action sebegai berikut:
#
#     a. Check Hero, check hero digunakan untuk melihat hero dan spell yang kita pilih.
#
#     b. Buy Item, buy item digunakan untuk membeli item yang tersedia dalam dictionary magic atau attack. Item magic HANYA bisa dibeli bagi hero yang mempunyai role sebagai Mage, sedangkan item Attack HANYA bisa dibeli bagi hero yang mempunyai role sebagai Assassin. Item disini fungsinya untuk menambahkan demage dari hero.
#
#     c. Fight Lord, fight lord digunakan untuk melawan lord. HP dari lord adalah 1000. User bisa menggunakan DMG hero ATAU DMG spell untuk melawan lord hingga HP lord = 0.
#
#     d. Exit, exit digunakan untuk keluar dari game.
#
# Hal-hal yang perlu diperhatikan dalam game:
# 1. Pada function buy item, pastikan jika gold hero < 250, maka user tidak dapat membeli item lagi.
# 2. HP lord tidak boleh di bawah 0.

# %%
allheroes = [{"Hero" : "Kagura", "Role" : "Mage", "DMG" : 350, "Gold" : 1000},
             {"Hero" : "Yve", "Role" : "Mage", "DMG" : 250, "Gold" : 1000},
             {"Hero" : "Lancelot", "Role" : "Assassin", "DMG" : 200, "Gold" : 1000},
             {"Hero" : "Lunox", "Role" : "Mage", "DMG" : 200, "Gold" : 1000},
             {"Hero" : "Hayabusa", "Role" : "Assassin", "DMG" : 300, "Gold" : 1000},
             {"Hero" : "Fanny", "Role" : "Assassin", "DMG" : 100, "Gold" : 1000},
             {"Hero" : "Natalia", "Role" : "Assassin", "DMG" : 150, "Gold" : 1000},
             {"Hero" : "Cecilion", "Role" : "Mage", "DMG" : 200, "Gold" : 1000}]

magic = [{"Name" : "Necklace of Durance", "DMG" : 50, "Price" : 250},
         {"Name" : "Lightning Truncheon", "DMG" : 100, "Price" : 300},
         {"Name" : "Blood Wings", "DMG" : 300, "Price" : 500}]

attack = [{"Name" : "War Axe", "DMG" : 100, "Price" : 250},
         {"Name" : "Endless Battle", "DMG" : 300, "Price" : 400},
         {"Name" : "Blade of Despair", "DMG" : 400, "Price" : 700}]

spell = [{"Name" : "Execute", "DMG": 300},
         {"Name" : "Flameshot", "DMG": 200}]

def chooseHero():
  print("Select 1 Hero you want to play: ")
  selectedhero = {}
  for i in range(len(allheroes)):
    print("Id : {}".format(i))
    print("Detail : {}".format(allheroes[i]))
  inputs = input("silahkan masukkan pilihan Id: ")
  try:
    selectedhero.update(allheroes[int(inputs)])
    return selectedhero
  except:
    return "Wrong Input!"

def chooseSpell(hero):
  selectedhero = hero
  print("\n{} - DMG {}\n".format(selectedhero["Hero"],selectedhero["DMG"]))
  for i in range(len(spell)):
      print("Id: {} : {} - DMG {}".format(i,spell[i]["Name"], spell[i]["DMG"]))
  inputs = input("Pilih Id spell yang akan dipakai? ")
  selectedhero["Spell"] = spell[int(inputs)]
  print("\n{} - DMG {} - Spell {}\n".format(selectedhero["Hero"],selectedhero["DMG"],selectedhero["Spell"]))
  return selectedhero

def buyItem(hero):
  selectedhero = hero
  print("\n{} - DMG {} - Gold {}\n".format(selectedhero["Hero"],selectedhero["DMG"],selectedhero["Gold"]))
  if selectedhero["Role"] == "Mage":
    for i in range(len(magic)):
      print("Id: {} : {} - DMG {} - Price {}".format(i, magic[i]["Name"], magic[i]["DMG"], magic[i]["Price"]))
    inputs = input("silahkan masukkan pilihan Id: ")
    try:
      if selectedhero["Gold"] < magic[int(inputs)]["Price"]:
        print("Gold not enough")
        return selectedhero
      else:
        selectedhero["DMG"] += magic[int(inputs)]["DMG"]
        selectedhero["Gold"] -= magic[int(inputs)]["Price"]
        print("\nBUYING SUCCESS")
        print("\n{} - DMG {} - Gold {}\n".format(selectedhero["Hero"],selectedhero["DMG"],selectedhero["Gold"]))
    except:
      return "Wrong Input!"
  elif selectedhero["Role"] == "Assassin":
    for i in range(len(attack)):
      print("Id: {} : {} - DMG {} - Price {}".format(i, attack[i]["Name"], attack[i]["DMG"], attack[i]["Price"]))
    inputs = input("silahkan masukkan pilihan Id: ")
    try:
      if selectedhero["Gold"] < attack[int(inputs)]["Price"]:
        print("Gold not enough")
        return selectedhero
      else:
        selectedhero["DMG"] += attack[int(inputs)]["DMG"]
        selectedhero["Gold"] -= attack[int(inputs)]["Price"]
        print("\nBUYING SUCCESS")
        print("\n{} - DMG {} - Gold {}".format(selectedhero["Hero"],selectedhero["DMG"],selectedhero["Gold"]))
    except:
      return "Wrong Input!"
  if selectedhero["Gold"] < 250:
    return selectedhero
  else:
    inputt = input("Ingin beli lagi? (y/n)")
    if inputt == "y" or inputt == "Y":
      buyItem(selectedhero)
      return selectedhero
    else:
      return selectedhero

def fightLord(hero):
  lord = 1000
  selectedhero = hero
  spell = selectedhero["Spell"]
  print("Fight Begin\n")
  print("Lord - HP: {}\n".format(lord))
  while lord > 0:
    print("0 || {} - DMG {}".format(selectedhero["Hero"], selectedhero["DMG"]))
    print("1 || {} - DMG {}".format(spell["Name"], spell["DMG"]))
    fight = input("Select 0 to fight with hero DMG or 1 to fight with Spell DMG: ")
    if fight == "0":
      lord -= selectedhero["DMG"]
    elif fight == "1":
      lord -= spell["DMG"]
    else:
      print("Wrong Input!")
    if lord > 0:
      print("\nLord - HP: {}\n".format(lord))
    else:
      lord = 0
      print("\nLord - HP: {}\n".format(lord))
      print("Challange Success\n")

def start():
  print("Welcome to mini Mobile Legends Game\n\n")
  hero = chooseHero()
  selectedherospell = chooseSpell(hero)
  flag = True
  while flag:
    print("Select the activity you want to do:")
    print("1. Check Hero")
    print("2. Buy Item")
    print("3. Fight Lord")
    print("4. Exit")
    inputs = input("Choose the number :) ")
    if inputs == "1":
      print("{} - {} - DMG {} - Spell {}".format(selectedherospell["Hero"], selectedherospell["Role"], 
                                             selectedherospell["DMG"], selectedherospell["Spell"]))
    elif inputs == "2":
      selectedherospell = buyItem(selectedherospell)
    elif inputs == "3":
      fightLord(selectedherospell)
    elif inputs == "4":
      print("Thank you for playing this game")
      flag = False
    else:
      return "Wrong Input"

start()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# ...

# %% [markdown]
# # PRAKTIKUM MODUL

# %% [markdown]
# Dengan diberikan dictionary allcharacter, sword, catalyst, dan polearm berikut ini,
# Buatlah simple gamification dengan ketentuan sebagai berikut:
#
# 1. Ketika game dijalankan maka user akan memilih 4 character yang akan dia mainkan. Dalam 4 character tersebut, user tidak boleh menginputkan character yang sama dua kali atau lebih, sehingga dalam 4 character tersebut terdapat 4 macam character yang berbeda. Tambahkan exception handling apabila user memasukkan inputan yang sama, maka program akan memberikan pesan error dan meminta user untuk menginputkan lagi.
#
# 2. Setelah user menentukan 4 charactersnya, maka user mamasuki main menu yang berisi action sebagao berikut:
#
#     a. Check Characters, check characters digunakan untuk melihat 4 detail characters yang sudah dipilih oleh user. Detail ini berisi keterangan: Nama - Element - Waepon - ATK.
#
#     b. Change Waepon, change waepon digunakan untuk mengganti senjata character. Alurnya sebagai berikut:
#
#         1) Pertama, user akan memilih satu dari 4 character yang dipilihnya untuk diganti senjatanya.
#         2) Selanjutnya, user akan memilih senjata yang dipakai oleh character tersebut. Character hanya dapat mengganti senjata sesuai dengan tipe senjatanya. Misal, Character yang mempunyai Waepon Type Sword, hanya bisa mengganti senjata pada dictionary Sword.
#         3) Apabila pergantian senjata sukses, maka sistem akan menampilkan lagi 4 characters yang dipilih user dengan salah satu characternya sudah diganti senjatanya.
#         4) Selanjutnya, sistem akan menanyakan lagi apakah user akan mengganti senjata lagi, jika iya maka sistem akan menjalankan kembali pada poin 1), jika tidak, maka sistem akan kembali ke main menu.
#
#     c. Fight Azhdaha, fight azhdaha digunakan untuk melawan azhdaha. HP dari azhdaha adalah 10000. User bisa memilih salah satu dari empat characters yang dipilihnya untuk melawan azdhaha. HP azhdaha akan berkurang sesuai ATK dari character yang dipilih oleh user. Bersamaan dengan hal tersebut, azhdaha akan mengalai elemental reaction sesuai dengan element characternya yang menyerangnya. Ulangi langkah tersebut sehingga HP dari azhdaha = 0.
#
#     d. Exit, exit digunakan untuk keluar dari game.
#
# Hal-hal yang perlu diperhatikan dalam game:
# 1. ATK character ditentukan dari ATK senjata dikali dengan pengkali element character. Pengkali element adalah sebagai berikut:
#     a. Cryo = 5
#
#     b. Electro = 4
#
#     c. Hydro = 3
#
#     d. Anemo = 2
#
#     Misal, jika Eula dipasangkan dengan waepon Song of Broken Pines, maka ATK Eula = 1500. Contoh lainnnya, misal Keqing dipasangkan dengan waepon Mistsplitter Reforged maka ATK Keqing = 800.
# 2. HP azhdaha tidak boleh di bawah 0.
# 3. Praktikan DILARANG INISIALISASI VARIABEL DILUAR FUNGSI kecuali dictionary yang disediakan. Semua element pada codingan tidak boleh berada diluar fungsi kecuali dictionary yang disediakan dan pemanggilan fungsi utama sebagaimana yang dicontohkan pada kegiatan percobaan.
#
# Lebih lanjut silahkan liat demo video di link youtube berikut: [link text](https://www.youtube.com/watch?v=B7QpKPLhSkY)

# %%
allcharacter = [{"Name" : "Eula", "Element" : "Cryo", "Waepon Type" : "Claymore", "Waepon" : "Waster Greatsword", "ATK" : 50},
                {"Name" : "Raiden Shogun", "Element" : "Electro", "Waepon Type" : "Polearm", "Waepon" : "Beginner's Protector", "ATK" : 40},
                {"Name" : "Sangonomiya Kokomi", "Element" : "Hydro", "Waepon Type" : "Catalyst", "Waepon" : "Apprentice's Notes", "ATK" : 30},
                {"Name" : "Jean", "Element" : "Anemo", "Waepon Type" : "Sword", "Waepon" : "Dull Blade", "ATK" : 20},
                {"Name" : "Mona", "Element" : "Hydro", "Waepon Type" : "Catalyst", "Waepon" : "Apprentice's Notes", "ATK" : 30},
                {"Name" : "Kaedahara Kazuha", "Element" : "Anemo", "Waepon Type" : "Sword", "Waepon" : "Dull Blade", "ATK" : 20},
                {"Name" : "Kamisato Ayaka", "Element" : "Cryo", "Waepon Type" : "Sword", "Waepon" : "Dull Blade", "ATK" : 50},
                {"Name" : "Keqing", "Element" : "Electro", "Waepon Type" : "Sword", "Waepon" : "Dull Blade", "ATK" : 40}]

sword = [{"Name" : "Mistsplitter Reforged", "ATK" : 200},
         {"Name" : "Aquila Favonia", "ATK" : 200},
         {"Name" : "Freedom-Sworn", "ATK" : 100},
         {"Name" : "Dull Blade", "ATK" : 10}]
catalyst = [{"Name" : "Everlasting Moonglow", "ATK" : 300},
            {"Name" : "Dodoco Tales", "ATK" : 200},
            {"Name" : "Solar Pearl", "ATK" : 200},
            {"Name" : "Apprentice's Notes", "ATK": 10}]
claymore = [{"Name" : "Song of Broken Pines", "ATK" : 300},
            {"Name" : "Skyward Pride", "ATK" : 200},
            {"Name" : "Akuoumaru", "ATK" : 100},
            {"Name" : "Waster Greatsword", "ATK" : 10}]
polearm = [{"Name" : "Engulfing Lightning", "ATK" : 300},
           {"Name" : "Staff of Homa", "ATK" : 250},
           {"Name" : "The Catch", "ATK" : 150},
           {"Name" : "Beginner's Protector", "ATK" : 10}]

def chooseHero1():
  global selectedhero1
  selectedhero1 = {}
  print("Select Hero 1 you want to play: ")
  for i in range(len(allheroes)):
    print("Id : {}".format(i))
    print("Detail : {}".format(allheroes[i]))
  inputs = input("silahkan masukkan pilihan Id: ")
  # input2 = input ("silahkan masukkan pilihan Id: ")
  try:
    selectedhero1.update(allheroes[int(inputs)])
    allheroes.pop (int (inputs))
    return allheroes
  except:
    return "Wrong Input!"

def chooseHero2():
  global selectedhero2
  selectedhero2 = {}
  print("Select Hero 2 you want to play: ")
  for i in range(len(allheroes)):
    print("Id : {}".format(i))
    print("Detail : {}".format(allheroes[i]))

  inputs = input("silahkan masukkan pilihan Id: ")
  # input2 = input ("silahkan masukkan pilihan Id: ")
  try:
    selectedhero2.update(allheroes[int(inputs)])
    allheroes.pop (int (inputs))
    return allheroes
  except:
    return "Wrong Input!"

def chooseHero3():
  global selectedhero3
  selectedhero3 = {}
  print("Select Hero 3 you want to play: ")
  inputs = input("silahkan masukkan pilihan Id: ")
  # input2 = input ("silahkan masukkan pilihan Id: ")
  try:
    selectedhero3.update(allheroes[int(inputs)])
    allheroes.pop (int (inputs))
    return allheroes
  except:
    return "Wrong Input!"

def chooseHero4():
  global selectedhero4
  selectedhero4 = {}
  print("Select Hero 4 you want to play: ")
  inputs = input("silahkan masukkan pilihan Id: ")
  # input2 = input ("silahkan masukkan pilihan Id: ")
  try:
    selectedhero4.update(allheroes[int(inputs)])
    allheroes.pop (int (inputs))
    return allheroes
  except:
    return "Wrong Input!"

def change():
  flag = True
  while flag:
    print ("Select the activity you want to do:")
    print ('1',selectedhero1)
    print ('2',selectedhero2)
    print ('3',selectedhero3)
    print ('4',selectedhero4)
    print ("5. Exit")
    inputs = input ("Choose the number :) ")
    if inputs == "1":
      weapon (selectedhero1)
    elif inputs == "2":
      weapon(selectedhero2)
    elif inputs == "3":
      weapon(selectedhero3)
    elif inputs == "4":
      weapon (selectedhero4)
    elif inputs == "5":
      print ("Thank you for playing this game")
      flag = False
    else:
      return "Wrong Input"

def choosefight():
  lord = 1000
  flag = True
  while flag:
    if lord <= 0:
      lord = 0
      print("\nLord - HP: {}\n".format(lord))
      print("Challange Success\n")
    else:
      print("\nLord - HP: {}\n".format(lord))
    print()
    print ("Select the activity you want to do:")
    print ('1',selectedhero1)
    print ('2',selectedhero2)
    print ('3',selectedhero3)
    print ('4',selectedhero4)
    print ("5. Exit")
    inputs = input ("Choose the number :) ")
    if inputs == "1":
      lord -= selectedhero1 ["ATK"]
    elif inputs == "2":
      lord -= selectedhero2 ["ATK"]
    elif inputs == "3":
      lord -= selectedhero3 ["ATK"]
    elif inputs == "4":
      lord -= selectedhero4 ["ATK"]
    elif inputs == "5":
      print ("Thank you for playing this game")
      flag = False
    else:
      return "Wrong Input"

# def fightLord(hero):
#   selectedhero = hero
#   print("Lord - HP: {}\n".format(lord))
#   lord -= selectedhero ["ATK"]

def weapon(hero):
  selectedhero = hero
  print("\n{} - {} - {} - {}\n".format(selectedhero["Name"],selectedhero["Element"],selectedhero["Waepon"],selectedhero["ATK"]))
  if selectedhero["Waepon Type"] == "Sword":
    for i in range(len(sword)):
      print("Id: {} : {} - ATK {}".format(i, sword[i]["Name"], sword[i]["ATK"]))
    inputs = input("silahkan masukkan pilihan Id: ")
    try:
      if selectedhero ["Element"] == "Cryo":
        selectedhero ["ATK"] = sword [int (inputs)] ["ATK"] * 5
      elif selectedhero ["Element"] == "Electro":
        selectedhero ["ATK"] = sword [int (inputs)] ["ATK"] * 4
      elif selectedhero ["Element"] == "Hydro":
        selectedhero ["ATK"] = sword [int (inputs)] ["ATK"] * 3
      elif selectedhero ["Element"] == "Anemo":
        selectedhero ["ATK"] = sword [int (inputs)] ["ATK"] * 2

      selectedhero ["Waepon"] = sword [int (inputs)] ["Name"]
      print ("\nBUYING SUCCESS")
      print ("\n{} - {} - ATK {} \n".format (selectedhero ["Name"],selectedhero ["Waepon"], selectedhero ["ATK"]))
    except:
      return "Wrong Input!"
  elif selectedhero["Waepon Type"] == "Catalyst":
    for i in range (len (catalyst)):
      print ("Id: {} : {} - ATK {}".format (i, catalyst [i] ["Name"], catalyst [i] ["ATK"]))
    inputs = input ("silahkan masukkan pilihan Id: ")
    try:
      if selectedhero ["Element"] == "Cryo":
        selectedhero ["ATK"] = catalyst [int (inputs)] ["ATK"] * 5
      elif selectedhero ["Element"] == "Electro":
        selectedhero ["ATK"] = catalyst [int (inputs)] ["ATK"] * 4
      elif selectedhero ["Element"] == "Hydro":
        selectedhero ["ATK"] = catalyst [int (inputs)] ["ATK"] * 3
      elif selectedhero ["Element"] == "Anemo":
        selectedhero ["ATK"] = catalyst [int (inputs)] ["ATK"] * 2

      selectedhero ["Waepon"] = catalyst [int (inputs)] ["Name"]
      print ("\nBUYING SUCCESS")
      print ("\n{} - {} - ATK {} \n".format (selectedhero ["Name"], selectedhero ["Waepon"], selectedhero ["ATK"]))
    except:
      return "Wrong Input!"
  elif selectedhero ["Waepon Type"] == "Claymore":
    for i in range (len (claymore)):
      print ("Id: {} : {} - ATK {}".format (i, claymore [i] ["Name"], claymore [i] ["ATK"]))
    inputs = input ("silahkan masukkan pilihan Id: ")
    try:
      if selectedhero ["Element"] == "Cryo":
        selectedhero ["ATK"] = claymore [int (inputs)] ["ATK"] * 5
      elif selectedhero ["Element"] == "Electro":
        selectedhero ["ATK"] = claymore [int (inputs)] ["ATK"] * 4
      elif selectedhero ["Element"] == "Hydro":
        selectedhero ["ATK"] = claymore [int (inputs)] ["ATK"] * 3
      elif selectedhero ["Element"] == "Anemo":
        selectedhero ["ATK"] = claymore [int (inputs)] ["ATK"] * 2

      selectedhero ["Waepon"] = claymore [int (inputs)] ["Name"]
      print ("\nBUYING SUCCESS")
      print ("\n{} - {} - ATK {}\n".format (selectedhero ["Name"], selectedhero ["Waepon"], selectedhero ["ATK"]))
    except:
      return "Wrong Input!"
  elif selectedhero ["Waepon Type"] == "Polearm":
    for i in range (len (polearm)):
      print ("Id: {} : {} - ATK {}".format (i, polearm [i] ["Name"], polearm [i] ["ATK"]))
    inputs = input ("silahkan masukkan pilihan Id: ")
    try:
      if selectedhero ["Element"] == "Cryo":
        selectedhero ["ATK"] = polearm [int (inputs)] ["ATK"] * 5
      elif selectedhero ["Element"] == "Electro":
        selectedhero ["ATK"] = polearm [int (inputs)] ["ATK"] * 4
      elif selectedhero ["Element"] == "Hydro":
        selectedhero ["ATK"] = polearm [int (inputs)] ["ATK"] * 3
      elif selectedhero ["Element"] == "Anemo":
        selectedhero ["ATK"] = polearm [int (inputs)] ["ATK"] * 2

      selectedhero ["Waepon"] = polearm [int (inputs)] ["Name"]
      print ("\nBUYING SUCCESS")
      print ("\n{} - {} - ATK {}\n".format (selectedhero ["Name"], selectedhero ["Waepon"], selectedhero ["ATK"]))
    except:
      return "Wrong Input!"

  inputt = input ("Ingin beli lagi? (y/n)")
  if inputt == "y" or inputt == "Y":
    weapon (selectedhero)
    return selectedhero
  else:
    return selectedhero




def start():
  print("Welcome to mini Mobile Legends Game\n\n")
  chooseHero1 ()
  chooseHero2 ()
  chooseHero3 ()
  chooseHero4 ()

  flag = True
  while flag:
    print("Select the activity you want to do:")
    print("1. Check Hero")
    print("2. Change Weapon")
    print("3. Fight Lord")
    print("4. Exit")
    inputs = input("Choose the number :) ")
    if inputs == "1":
      print(selectedhero1)
      print (selectedhero2)
      print (selectedhero3)
      print (selectedhero4)
      # print("{} - {} - DMG {} ".format(selectedhero1["Hero"], selectedhero1["Waepon Type"],
      #                                        selectedhero1["ATK"]))
    elif inputs == "2":
      change()
    elif inputs == "3":
      choosefight()
    elif inputs == "4":
      print("Thank you for playing this game")
      flag = False
    else:
      return "Wrong Input"

start()
# Out:
# Welcome to mini Mobile Legends Game
#
#
# Select 1 Hero you want to play:
# Id : 0
# Detail : {'Name': 'Eula', 'Element': 'Cryo', 'Waepon Type': 'Claymore', 'Waepon': 'Waster Greatsword', 'ATK': 50}
# Id : 1
# Detail : {'Name': 'Raiden Shogun', 'Element': 'Electro', 'Waepon Type': 'Polearm', 'Waepon': "Beginner's Protector", 'ATK': 40}
# Id : 2
# Detail : {'Name': 'Sangonomiya Kokomi', 'Element': 'Hydro', 'Waepon Type': 'Catalyst', 'Waepon': "Apprentice's Notes", 'ATK': 30}
# Id : 3
# Detail : {'Name': 'Jean', 'Element': 'Anemo', 'Waepon Type': 'Sword', 'Waepon': 'Dull Blade', 'ATK': 20}
# Id : 4
# Detail : {'Name': 'Mona', 'Element': 'Hydro', 'Waepon Type': 'Catalyst', 'Waepon': "Apprentice's Notes", 'ATK': 30}
# Id : 5
# Detail : {'Name': 'Kaedahara Kazuha', 'Element': 'Anemo', 'Waepon Type': 'Sword', 'Waepon': 'Dull Blade', 'ATK': 20}
# Id : 6
# Detail : {'Name': 'Kamisato Ayaka', 'Element': 'Cryo', 'Waepon Type': 'Sword', 'Waepon': 'Dull Blade', 'ATK': 50}
# Id : 7
# ...

# %% [markdown]
# INDIKATOR PENILAIAN
#
# 1. Program berjalan sesuai dengan instruksi modul (60 Poin)
# 2. Menggunakan minimal 2 function high order, rekursif, lambda expression, **DAN/ATAU** pure function. (20 Poin)
# 3. Menggunakan manipulasi dictionary (10 poin)
# 4. Menggunakan Closures (10 poin)
#
# Opsional
# 1. Tambahkan exception handling jika user mamasukkan inputan yang salah (15 poin)
